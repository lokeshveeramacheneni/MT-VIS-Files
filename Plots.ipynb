# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tikzplotlib import save
import json

# %%
df = pd.read_csv('./values_miou_OA.csv')
print(df.head())

# %%
df = df.sort_values('MeanIOU')
miou, acc = df['MeanIOU'], df['Accuracy']

# %%
plt.figure(figsize=(5, 5))
plt.plot(range(1, 21), miou, c='g')
plt.scatter(range(1, 21), miou, c='g')
plt.xlabel('Ensemble size')
plt.ylabel('mean Intersection-over-Union')
plt.xticks(range(1, 21))
plt.grid('equal')
#save('miou.tex')
plt.show()
plt.figure()
plt.plot(range(1, 21), acc, c='g')
plt.scatter(range(1, 21), acc, c='g')
plt.xlabel('Ensemble size')
plt.ylabel('Accuracy')
plt.xticks(range(1, 21))
plt.grid('equal')
save('acc_de.tex')
plt.show()

# %% [markdown]
# ## Deep ensembles

# %%
entropies = []
probs = []
with open('entropy_sem3d.json') as fp:
    entropies = json.load(fp)
with open('probs_sem3d.json') as fp:
    probs = json.load(fp)

# %%
plt.figure()
key_v = []
value_v = []
for key, value in entropies.items():
    key_v.append(int(key))
    value_v.append(value)
    plt.scatter(int(key), value, c='g')
plt.plot(key_v, value_v, c='g')
plt.xticks(range(1, 21))
plt.xlabel('Ensemble size')

plt.grid()
plt.show()

# %% [markdown]
# # Semantic3D Vs S3DIS
# ## Maximum Softmax Probability

# %%
#de_mean_id_probs, de_mean_ood_probs = [], []
#de_std_id_probs, de_std_ood_probs = [], []
#with open('probabs_mean_sem3d_de.json') as fp:
#    de_mean_id_probs = json.load(fp)
#with open('probabs_std_sem3d_de.json') as fp:
#    de_std_id_probs = json.load(fp)
#with open('probabs_mean_s3dis_de.json') as fp:
#    de_mean_ood_probs = json.load(fp)
#with open('probabs_std_s3dis_de.json') as fp:
#    de_std_ood_probs = json.load(fp)   
de_mean_id_probs = [0.9186214295186658, 0.9016557590957764, 0.9145112444914671, 0.9188853788628388, 
                    0.9241038612957605, 0.9277365957254222, 0.9276979068324764, 0.9274549686441541, 
                    0.9277589065669672, 0.9277775130755371, 0.9275190656358973, 0.9192083633748983, 
                    0.9199109046540659, 0.9152296671076486, 0.9163326630875693, 0.9175922716560855, 
                    0.9178793453933964, 0.919010758774066, 0.9182155865425193, 0.9189364600320454]
de_std_id_probs = [0.15646803895498457, 0.14749297246316495, 0.132997944414521, 0.12672475576014353,
                   0.12139232850083763, 0.11986420664514041, 0.1195293929341584, 0.11941800912295097, 
                   0.11966766463719837, 0.11851962756294379, 0.11870886236154592, 0.12126964490156071,
                   0.12100237422420136, 0.12223059933696828, 0.12140075205670685, 0.12022810296662458,
                   0.1203228142938779, 0.11967938894317186, 0.12031048964346197, 0.11954683726068975]
de_mean_ood_probs = [0.8706909178669325, 0.7585799786452672, 0.7136780014924322, 0.7463904915621072, 
                     0.7650036575818918, 0.760418134082552, 0.7361617705400628, 0.7339487466265024, 
                     0.7205777843106275, 0.7322778024430956, 0.7390827044534817, 0.7474155656705578, 
                     0.7500200190099446, 0.741732982099111, 0.7241542064855301, 0.7238940898522972, 
                     0.7068779797626853, 0.7085387459332205, 0.7153733715152254, 0.7153733715152254]
de_std_ood_probs = [0.18517485131133737, 0.21809501820686059, 0.1601883389331294, 0.1605964794617701, 
                    0.1531825042542984, 0.15436261214000122, 0.15199286450193383, 0.1615681405991734, 
                    0.15191519471776863, 0.14942986250211188, 0.15000500854739174, 0.15243813192784697, 
                    0.15118221813256297, 0.143411731867469, 0.13281258669962487, 0.1335773546841656, 
                    0.13576643812650602, 0.1380969250859795, 0.13876150811094917, 0.13876150811094917]

# %%
fo_mean_id_probs, fo_mean_ood_probs = [], []
fo_std_id_probs, fo_std_ood_probs = [], []
with open('probabs_mean_sem3d_fout.json') as fp:
    fo_mean_id_probs = json.load(fp)
with open('probabs_std_sem3d_fout.json') as fp:
    fo_std_id_probs = json.load(fp)
with open('probabs_mean_s3dis_fout.json') as fp:
    fo_mean_ood_probs = json.load(fp)
with open('probabs_std_s3dis_fout.json') as fp:
    fo_std_ood_probs = json.load(fp)

fo_mean_id_probs = [0.8827576641859722, 0.8646691322740819, 0.8608504107626354, 0.8603049523768415, 
                    0.8555954842617287, 0.8576969048746941, 0.8582710274071359, 0.8594689726344894, 
                    0.8588559851628557, 0.8572655147064041, 0.8511539145144409, 0.852445894534432, 
                    0.8538185403756476, 0.8536738707382457, 0.8528795999396045, 0.8533378116571707, 
                    0.8547542587736614, 0.8542475739148745, 0.8536277653283998, 0.8535462057813539]
fo_std_id_probs = [0.16072468506836862, 0.1737870739028542, 0.17625926205364995, 0.17510465367988354, 0.17872456600447295, 0.17637505614527507, 0.17511264743783178, 0.17372993288204022, 0.1740799941541999, 0.17619417448852395, 0.18188768247397497, 0.18038775312637131, 0.17870992917152984, 0.1787580412694874, 0.17985152584499495, 0.17891804507133865, 0.17744609439037876, 0.17833009585575968, 0.17911214764851097, 0.17909581102082847]

# %%
print(fo_std_ood_probs)
# Out:
# {'1': 0.0, '2': 2.7755575615628914e-17, '3': 2.7755575615628914e-17, '4': 2.7755575615628914e-17, '5': 2.7755575615628914e-17, '6': 2.7755575615628914e-17, '7': 0.0, '8': 2.7755575615628914e-17, '9': 2.7755575615628914e-17, '10': 2.7755575615628914e-17, '11': 2.7755575615628914e-17, '12': 0.0, '13': 0.0, '14': 5.551115123125783e-17, '15': 2.7755575615628914e-17, '16': 2.7755575615628914e-17, '17': 0.0, '18': 5.551115123125783e-17, '19': 5.551115123125783e-17, '20': 0.0}

# %%
plt.figure(figsize=(10, 7))
key_, value_, error_ = [], [], []
for key, value in fo_mean_id_probs.items():
    key_.append(int(key))
    value_.append(value)
    error_.append(fo_std_id_probs[key])
    plt.scatter(int(key), value, c='g')
plt.plot(key_, value_, c='g', label='Flipout-Semantic3D')
high_error = []
for i in range(0, len(value_)):
    if value_[i]+error_[i] > 1:
        high_error.append(1)
    else:
        high_error.append(value_[i]+error_[i])
plt.fill_between(key_, np.asarray(value_)-np.asarray(error_), high_error, color='blue', alpha=0.2)
#plt.errorbar(key_, value_, yerr=error_, c='g', label='Flipout-Semantic3D')
key_, value_, error_ = [], [], []
for key, value in fo_mean_ood_probs.items():
    key_.append(int(key))
    value_.append(value)
    error_.append(fo_std_ood_probs[key])
    plt.scatter(int(key), value, c='r')
plt.plot(key_, value_, c='r', label='Flipout-S3DIS')
#plt.errorbar(key_, value_, yerr=error_, c='r', label='Flipout-S3DIS')
plt.fill_between(key_, np.asarray(value_)-np.asarray(error_), np.asarray(value_)+np.asarray(error_), color='gray', alpha=0.2)

plt.grid('equal')
plt.legend(loc='lower left', fontsize=16)
plt.xticks(range(1, 21), fontsize=18)
plt.yticks(np.arange(0.55, 1.05, 0.05), fontsize=18)
plt.xlabel('Number of passes', fontsize=18)
plt.ylabel('Mean probability score', fontsize=18)
plt.savefig('Flipout_MSP.pdf', dpi=600, bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(10, 7))
key_, value_, error_ = [], [], []
for key, value in de_mean_id_probs.items():
    key_.append(int(key))
    value_.append(value)
    error_.append(de_std_id_probs[key])
    plt.scatter(int(key), value, c='g')
plt.plot(key_, value_, c='g', label='Ensemble-Semantic3D')
high_error = []
for i in range(0, len(value_)):
    if value_[i]+error_[i] > 1:
        high_error.append(1)
    else:
        high_error.append(value_[i]+error_[i])
plt.fill_between(key_, np.asarray(value_)-np.asarray(error_), high_error, color='blue', alpha=0.2)

key_, value_, error_ = [], [], []
for key, value in de_mean_ood_probs.items():
    key_.append(int(key))
    value_.append(value)
    error_.append(de_std_ood_probs[key])
    plt.scatter(int(key), value, c='r')
plt.plot(key_, value_, c='r', label='Ensemble-S3DIS')
plt.fill_between(key_, np.asarray(value_)-np.asarray(error_), np.asarray(value_)+np.asarray(error_), color='blue', alpha=0.2)
plt.grid('equal')
plt.legend(loc='lower left', fontsize=16)
plt.xticks(range(1, 21), fontsize=18)
plt.yticks(np.arange(0.55, 1.05, 0.05), fontsize=18)
plt.xlabel('Ensemble size', fontsize=18)
plt.ylabel('Mean probability score', fontsize=18)
plt.savefig('Ensemble_MSP.pdf', dpi=600, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Entropy

# %%
de_mean_id_probs, de_mean_ood_probs = [], []
de_std_id_probs, de_std_ood_probs = [], []
with open('entrops_mean_sem3d_de.json') as fp:
    de_mean_id_probs = json.load(fp)
with open('entrops_std_sem3d_de.json') as fp:
    de_std_id_probs = json.load(fp)
with open('entrops_mean_s3dis_de.json') as fp:
    de_mean_ood_probs = json.load(fp)
with open('entrops_std_s3dis_de.json') as fp:
    de_std_ood_probs = json.load(fp)

# %%
fo_mean_id_probs, fo_mean_ood_probs = [], []
fo_std_id_probs, fo_std_ood_probs = [], []
with open('entrops_mean_sem3d_fout.json') as fp:
    fo_mean_id_probs = json.load(fp)
with open('entrops_std_sem3d_fout.json') as fp:
    fo_std_id_probs = json.load(fp)
with open('entrops_mean_s3dis_fout.json') as fp:
    fo_mean_ood_probs = json.load(fp)
with open('entrops_std_s3dis_fout.json') as fp:
    fo_std_ood_probs = json.load(fp)

# %%
plt.figure(figsize=(10, 7))
key_, value_, error_ = [], [], []
for key, value in fo_mean_id_probs.items():
    key_.append(int(key))
    value_.append(value)
    error_.append(fo_std_id_probs[key])
    plt.scatter(int(key), value, c='g')
plt.plot(key_, value_, c='g', label='Flipout-Semantic3D')
high_error = []
for i in range(0, len(value_)):
    if value_[i]-error_[i] < 0:
        high_error.append(0)
    else:
        high_error.append(value_[i]-error_[i])
plt.fill_between(key_, high_error, np.asarray(value_)+np.asarray(error_), color='blue', alpha=0.2)
#plt.errorbar(key_, value_, yerr=error_, c='g', label='Flipout-Semantic3D')
key_, value_, error_ = [], [], []
for key, value in fo_mean_ood_probs.items():
    key_.append(int(key))
    value_.append(value)
    error_.append(fo_std_ood_probs[key])
    plt.scatter(int(key), value, c='r')
plt.plot(key_, value_, c='r', label='Flipout-S3DIS')
#plt.errorbar(key_, value_, yerr=error_, c='r', label='Flipout-S3DIS')
plt.fill_between(key_, np.asarray(value_)-np.asarray(error_), np.asarray(value_)+np.asarray(error_), color='gray', alpha=0.2)

plt.grid('equal')
plt.legend(loc='lower left', fontsize=16)
plt.xticks(range(1, 21), fontsize=18)
plt.yticks(fontsize=18)
plt.xlabel('Number of passes', fontsize=18)
plt.ylabel('Mean entropy score', fontsize=18)
plt.savefig('Flipout_Entropy.pdf', dpi=600, bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(10, 7))
key_, value_, error_ = [], [], []
for key, value in de_mean_id_probs.items():
    key_.append(int(key))
    value_.append(value)
    error_.append(de_std_id_probs[key])
    plt.scatter(int(key), value, c='g')
plt.plot(key_, value_, c='g', label='Ensemble-Semantic3D')
high_error = []
for i in range(0, len(value_)):
    if value_[i]-error_[i] < 0:
        high_error.append(0)
    else:
        high_error.append(value_[i]-error_[i])
plt.fill_between(key_, high_error, np.asarray(value_)+np.asarray(error_), color='blue', alpha=0.2)

key_, value_, error_ = [], [], []
for key, value in de_mean_ood_probs.items():
    key_.append(int(key))
    value_.append(value)
    error_.append(de_std_ood_probs[key])
    plt.scatter(int(key), value, c='r')
plt.plot(key_, value_, c='r', label='Ensemble-S3DIS')
plt.fill_between(key_, np.asarray(value_)-np.asarray(error_), np.asarray(value_)+np.asarray(error_), color='blue', alpha=0.2)
plt.grid('equal')
plt.legend(loc='lower left', fontsize=16)
plt.xticks(range(1, 21), fontsize=18)
plt.yticks(fontsize=18)
plt.xlabel('Ensemble size', fontsize=18)
plt.ylabel('Mean entropy score', fontsize=18)
plt.savefig('Ensemble_Entropy.pdf', dpi=600, bbox_inches='tight')
plt.show()

# %% [markdown]
# # Semantic3D Vs Semantic3D_Ohne_Farbe

# %%
de_mean_id_probs, de_mean_ood_probs = [], []
de_std_id_probs, de_std_ood_probs = [], []
with open('probabs_mean_sem3d_de.json') as fp:
    de_mean_id_probs = json.load(fp)
with open('probabs_std_sem3d_de.json') as fp:
    de_std_id_probs = json.load(fp)
with open('probabs_mean_sem3d_of_de.json') as fp:
    de_mean_ood_probs = json.load(fp)
with open('probabs_std_sem3d_of_de.json') as fp:
    de_std_ood_probs = json.load(fp)

# %%
plt.figure(figsize=(10, 7))
key_, value_, error_ = [], [], []
for key, value in de_mean_id_probs.items():
    key_.append(int(key))
    value_.append(value)
    error_.append(de_std_id_probs[key])
    plt.scatter(int(key), value, c='g')
plt.plot(key_, value_, c='g', label='Ensemble-Semantic3D')
high_error = []
for i in range(0, len(value_)):
    if value_[i]+error_[i] > 1:
        high_error.append(1)
    else:
        high_error.append(value_[i]+error_[i])
plt.fill_between(key_, np.asarray(value_)-np.asarray(error_), high_error, color='blue', alpha=0.5)

key_, value_, error_ = [], [], []
for key, value in de_mean_ood_probs.items():
    key_.append(int(key))
    value_.append(value)
    error_.append(de_std_ood_probs[key])
    plt.scatter(int(key), value, c='r')
plt.plot(key_, value_, c='r', label='Ensemble-Semantic3D without Color')
high_error = []
for i in range(0, len(value_)):
    if value_[i]+error_[i] > 1:
        high_error.append(1)
    else:
        high_error.append(value_[i]+error_[i])
plt.fill_between(key_, np.asarray(value_)-np.asarray(error_), high_error, color='yellow', alpha=0.5)
plt.grid('equal')
plt.legend(loc='lower left', fontsize=16)
plt.xticks(range(1, 21), fontsize=18)
plt.yticks(np.arange(0.55, 1.05, 0.05), fontsize=18)
plt.xlabel('Ensemble size', fontsize=18)
plt.ylabel('Mean probability score', fontsize=18)
plt.savefig('Ensemble_MSP_color_no_color.pdf', dpi=600, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Entropy values

# %%
de_mean_id_probs, de_mean_ood_probs = [], []
de_std_id_probs, de_std_ood_probs = [], []
with open('entrops_mean_sem3d_de.json') as fp:
    de_mean_id_probs = json.load(fp)
with open('entrops_std_sem3d_de.json') as fp:
    de_std_id_probs = json.load(fp)
with open('entrops_mean_sem3d_of_de.json') as fp:
    de_mean_ood_probs = json.load(fp)
with open('entrops_std_sem3d_of_de.json') as fp:
    de_std_ood_probs = json.load(fp)

# %%
plt.figure(figsize=(10, 7))
key_, value_, error_ = [], [], []
for key, value in de_mean_id_probs.items():
    key_.append(int(key))
    value_.append(value)
    error_.append(de_std_id_probs[key])
    plt.scatter(int(key), value, c='g')
plt.plot(key_, value_, c='g', label='Ensemble-Semantic3D')
high_error = []
for i in range(0, len(value_)):
    if value_[i]-error_[i] < 0:
        high_error.append(0)
    else:
        high_error.append(value_[i]-error_[i])
plt.fill_between(key_, high_error, np.asarray(value_)+np.asarray(error_), color='blue', alpha=0.5)

key_, value_, error_ = [], [], []
for key, value in de_mean_ood_probs.items():
    key_.append(int(key))
    value_.append(value)
    error_.append(de_std_ood_probs[key])
    plt.scatter(int(key), value, c='r')
plt.plot(key_, value_, c='r', label='Ensemble-Semantic3D without Color')
high_error = []
for i in range(0, len(value_)):
    if value_[i]-error_[i] < 0:
        high_error.append(0)
    else:
        high_error.append(value_[i]-error_[i])
plt.fill_between(key_, high_error, np.asarray(value_)+np.asarray(error_), color='yellow', alpha=0.5)
plt.grid('equal')
plt.legend(loc='lower left', fontsize=16)
plt.xticks(range(1, 21), fontsize=18)
plt.yticks(fontsize=18)
plt.xlabel('Ensemble size', fontsize=18)
plt.ylabel('Mean entropy score', fontsize=18)
plt.savefig('Ensemble_Entropy_color_no_color.pdf', dpi=600, bbox_inches='tight')
plt.show()
